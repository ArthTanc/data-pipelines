# %%
1
# Out:
# Running cells with 'my-airflow-project (3.13.2) (Python 3.13.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/arthur.leite/Projects/data-pipelines/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
